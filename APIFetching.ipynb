# %%
# API fetching 
#pip install requests

import requests
import pandas as pd

# URL to fetch (note: Kaggle might require authentication for actual datasets)
url = "https://www.kaggle.com"

# Send GET request
response = requests.get(url)

response

df =pd.DataFrame(response)
df.head(100)
# Out:
#                                                     0
# 0   b'\r\n\r\n<!DOCTYPE html>\r\n<html lang="en">\...
# 1   b'eta charset="utf-8" />\r\n    <meta name="ro...
# 2   b'rld&#x2019;s largest data science community ...
# 3   b'    <meta name="viewport" content="width=dev...
# 4   b'theme-color" content="#008ABC" />\r\n  <scri...
# 5   b'artTime"] = 1749087522670;\r\n    window["pa...
# 6   b'().getTime();\r\n  </script>\r\n  <script no...
# 7   b'nt" async defer></script>\r\n  <script nonce...
# 8   b'-v4/jupyterlab-index-7ae4d57096a7ae9b9046.ht...
# 9   b'sorigin="anonymous" /><link rel="preconnect"...
# 10  b'ge.googleapis.com" /><link rel="preconnect" ...
# 11  b'shortcut icon" type="image/x-icon" id="dynam...
# 12  b'="use-credentials">\r\n\r\n\r\n  <link rel="...
# 13  b'.googleapis.com/css?family=Inter:400,400i,50...
# 14  b'f="https://fonts.googleapis.com/css2?family=...
# 15  b'ef="https://fonts.googleapis.com/css?family=...
# ...
